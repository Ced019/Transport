# %%
import numpy as np
from sympy import *
from fractions import *
import matplotlib as mpl
init_printing(use_latex=True)

# %%
#Définition des variables pour la fonction objectif
C_1, C_2, C_3, C_4, t_1, t_2, t, E, D, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, s1, s2 = symbols('C_1, C_2, C_3, C_4, t_1, t_2, t, E, D, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, s1, s2', real=True)

# %%
#Portion de la fonction objectif pour les véhicules à essence
O1 = (C_1*(t/100)*(E*s1+D*s2)*x1)+(C_2*(t/100)*(E*s1+D*s2)*x2)+(C_3*(t/100)*(E*s1+D*s2)*x3)+(C_4*(t/100)*(E*s1+D*s2)*x4)

# %%
#Portion de la fonction objectif pour les véhicules hybrides
O2 = (C_1*(t/200)*(E*s1+D*s2)+0.028*19.9*(t/200))*x5+(C_2*(t/200)*(E*s1+D*s2)+0.028*19.9*(t/200))*x6+(C_3*(t/200)*(E*s1+D*s2)+0.028*19.9*(t/200))*x7+(C_4*(t/200)*(E*s1+D*s2)+0.028*19.9*(t/200))*x8

# %%
#Portion de la fonction objectif pour les véhicules à essence
O3= (0.028*19.9*(t/100))*x9+(0.028*19.9*(t/100))*x10+(0.028*19.9*(t/100))*x11+(0.028*19.9*(t/100))*x12

# %%
# Fusion de O1, O2 et O3 pour obtenir la fonction objectif
Ec1 = O1+O2+O3

# %%
#Substitution de certaines variables par leur valeur fixe
Ec2 = Ec1.subs({C_1:8.55, C_2:9.41, C_3:11.47, C_4:12.66, D:2.7, E:2.3})

# %%
#Définition des variables pour la contrainte budget
p1, p2, a1, a2, vi, vm, m=symbols('p1, p2, a1, a2, vi, vm, m')

# %%
#Portion de la contrainte budget pour les véhicules à essence
B1=(C_1*(t/100)*(E*s1+D*s2)+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))
    +p2*vm+60+125)*x1+(C_2*(t/100)*(E*s1+D*s2)+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))
    +a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x2+(C_3*(t/100)*(E*s1+D*s2)
    +p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x3+(C_4*(t/100)*(E*s1+D*s2)+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x4

# %%
#Portion de la contrainte budget pour les véhicules hybrides
B2=(C_1*(t/200)*(E*s1+D*s2)+(19.9*0.11209*(t/200))+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x5+(C_2*(t/200)*(E*s1+D*s2)+(19.9*0.11209*(t/200))+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x6+(C_3*(t/200)*(E*s1+D*s2)+(19.9*0.11209*(t/200))+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x7+(C_4*(t/200)*(E*s1+D*s2)+(19.9*0.11209*(t/200))+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x8

# %%
#Portion de la contrainte budget pour les véhicules électriques
B3=(19.9*0.11209*(t/100)+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x9+(19.9*0.11209*(t/100)+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x10+(19.9*0.11209*(t/100)+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x11+(19.9*0.11209*(t/100)+p1*(a1*(vi*(0.8**((m-1)/12)-0.8**(m/12)))+a2*(0.8*vi*(0.9**((m-13)/12)-0.9**((m-12)/12))))+p2*vm+60+125)*x12

# %%
#Fusion de B1, B2 et B3 pour obtenir l'équation de la contrainte budget B
B=B1+B2+B3

# %%
#Substitution de variables par leur valeur fixe
Bc= B.subs({C_1:8.55, C_2:9.41, C_3:11.47, C_4:12.66, D:1.749, E:1.459})

# %%
# Les simulations commencent
# Le premier véhicule étudié est X1 (Berline à essence)
# Ses caractéristiques sont : S1=1 (essence traditionnel), P1=1 (possédée), A1=1 (moins d'un an), M=1 (elle a un mois),
# Vi=10000 (valeur initiale de 10 000$) et Vm=400 (versements mensuels de 400$ si elle est louée)
X1=1
X2=0
X3=0
X4=0
X5=0
X6=0
X7=0
X8=0
X9=0
X10=0
X11=0
X12=0
S1=1
P1=1
A1=1
M=1
Vi=10000
Vm=400
while X1==1:
    #Si S1=1, S2=0 (un seul type d'hydrocarbure)
    while S1==1:
        S2=0
        #Si P1=1, P2=0 (elle ne peut pas être achetée et louée)
        while P1==1:
            P2=0
            #Si A1=1, A2=0 (la voiture ne peut pas avoir moins et plus d'un an)
            while A1==1:
                A2=0
                #Tant que la valeur initiale ne dépasse pas 60 000, je reste dans cette boucle
                while Vi<=60000:
                    #Tant que le nombre de mois ne dépasse pas 12, je reste dans cette boucle
                    while M<=12:
                        #On pose que la valeur minimale de t1 est 1400km
                        t1=1400
                        #Tant et aussi longtemps que t ne dépasse pas 2600, je reste dans cette boucle
                        while t1<=2600:
                            #Je lui demande de substituer les variables de l'équation par leurs valeurs (.subs)
                            #Je lui demande aussi de print le résultat avec ses caractéristiques
                            print('u_b_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                            #J'augmente t1 de 300. La boucle recommence
                            t1=t1+300
                        #J'augmente M de 3. La boucle while M<=12 recommence
                        M=M+3
                    #J'augmente Vi de 5000. La boucle while Vi<=5000 recommence. Je réinitialise aussi la variable M
                    Vi=Vi+5000
                    M=1
                #J'ai terminé les cas de figure des voitures ayant moins d'un an
                #On passe de A1=1 à A1=0 et de A2=0 à A2=1 pour exprimer ce changement
                #La nouvelle valeur M de départ est 13. Je réinitialise Vi à 10 000.
                A1=0
                A2=1
                M=13
                Vi=10000
                #Le principe est le même que plus haut
                while Vi<=60000:
                    while 13<=M<=120:
                        t1=1400
                        while t1<=2600:
                            print('u_b_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                            t1=t1+300
                        M=M+3
                    Vi=Vi+5000
                    M=13
            #J'ai terminé les cas de figure des voitures achetées. Je passe aux voitures louées.
            #On passe de P1=1 à P1=0 et P2=1 à P2=0 pour exprimer ce changement
            P1=0
            P2=1
            #Les versements mensuels varient de 400 à 800 par bonds de 50
            while Vm<=800:
                t1=1400
                while t1<=2600:
                    print('u_b_foss_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                    t1=t1+300
                Vm=Vm+50
        #J'ai terminé les cas de figure des berlines à essence traditionnelle. Passons aux berlines à essence diesel
        #On passe de S1=1 à S1=0 et de S2=0 à S2=1 pour exprimer ce changement
        #On refait exactement le même processus que précédemment
        S1=0
        S2=1
        P1=1
        Vm=400
        Vi=10000
        A1=1
        M=1
        t1=1400
        while S2==1:
            while P1==1:
                P2=0
                while A1==1:
                    A2=0
                    while Vi<=60000:
                        while M<=12:
                            t1=1400
                            while t1<=2600:
                                print('u_b_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                t1=t1+300
                            M=M+3
                        Vi=Vi+5000
                        M=1
                    A1=0
                    A2=1
                    M=13
                    Vi=10000
                    while Vi<=60000:
                        while 13<=M<=120:
                            t1=1400
                            while t1<=2600:
                                print('u_b_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                t1=t1+300
                            M=M+3
                        Vi=Vi+5000
                        M=13
                P1=0
                P2=1
                while Vm<=800:
                    t1=1400
                    while t1<=2600:
                        print('u_b_foss_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                        t1=t1+300
                    Vm=Vm+50
            S2=0
    #J'ai terminé les cas de figure des berlines à essence. Je peux passer aux berlines hybrides
    #Je passe de X2=0 à X2=1 pour exprimer ce changement
    #Je réinitialise tous les paramètres pour redémarrer les simulations
    X2=1
    P1=1
    A1=1
    M=1
    Vi=10000
    Vm=400
    t1=1400
    S1=1
    S2=0
    #Tant que j'ai le type de véhicule X2, je ne peux pas avoir X1. J'attribue un coefficient nul à X1
    while X2==1:
        X1=0
        while S1==1:
            S2=0
            while P1==1:
                P2=0
                while A1==1:
                    A2=0
                    while Vi<=60000:
                        while M<=12:
                            t1=1400
                            while t1<=2600:
                                print('u_co_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                t1=t1+300
                            M=M+3
                        Vi=Vi+5000
                        M=1
                    A1=0
                    A2=1
                    M=13
                    Vi=10000
                    while Vi<=60000:
                        while 13<=M<=120:
                            t1=1400
                            while t1<=2600:
                                print('u_co_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                t1=t1+300
                            M=M+3
                        Vi=Vi+5000
                        M=13
                P1=0
                P2=1
                while Vm<=800:
                    t1=1400
                    while t1<=2600:
                        print('u_co_foss_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                        t1=t1+300
                    Vm=Vm+50
            S1=0
            S2=1
            P1=1
            Vm=400
            Vi=10000
            A1=1
            M=1
            t1=1400
            while S2==1:
                while P1==1:
                    P2=0
                    while A1==1:
                        A2=0
                        while Vi<=60000:
                            while M<=12:
                                t1=1400
                                while t1<=2600:
                                    print('u_co_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                    t1=t1+300
                                M=M+3
                            Vi=Vi+5000
                            M=1
                        A1=0
                        A2=1
                        M=13
                        Vi=10000
                        while Vi<=60000:
                            while 13<=M<=120:
                                t1=1400
                                while t1<=2600:
                                    print('u_co_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                    t1=t1+300
                                M=M+3
                            Vi=Vi+5000
                            M=13
                    P1=0
                    P2=1
                    while Vm<=800:
                        t1=1400
                        while t1<=2600:
                            print('u_co_foss_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                            t1=t1+300
                        Vm=Vm+50
                S2=0
        X3=1
        P1=1
        A1=1
        M=1
        Vi=10000
        Vm=400
        t1=1400
        S1=1
        S2=0
        while X3==1:
            X1=0
            X2=0
            while S1==1:
                S2=0
                while P1==1:
                    P2=0
                    while A1==1:
                        A2=0
                        while Vi<=60000:
                            while M<=12:
                                t1=1400
                                while t1<=2600:
                                    print('u_vus_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                    t1=t1+300
                                M=M+3
                            Vi=Vi+5000
                            M=1
                        A1=0
                        A2=1
                        M=13
                        Vi=10000
                        while Vi<=60000:
                            while 13<=M<=120:
                                t1=1400
                                while t1<=2600:
                                    print('u_vus_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                    t1=t1+300
                                M=M+3
                            Vi=Vi+5000
                            M=13
                    P1=0
                    P2=1
                    while Vm<=800:
                        t1=1400
                        while t1<=2600:
                            print('u_vus_foss_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                            t1=t1+300
                        Vm=Vm+50
                S1=0
                S2=1
                P1=1
                Vm=400
                Vi=10000
                A1=1
                M=1
                t1=1400
                while S2==1:
                    while P1==1:
                        P2=0
                        while A1==1:
                            A2=0
                            while Vi<=60000:
                                while M<=12:
                                    t1=1400
                                    while t1<=2600:
                                        print('u_vus_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                        t1=t1+300
                                    M=M+3
                                Vi=Vi+5000
                                M=1
                            A1=0
                            A2=1
                            M=13
                            Vi=10000
                            while Vi<=60000:
                                while 13<=M<=120:
                                    t1=1400
                                    while t1<=2600:
                                        print('u_vus_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                        t1=t1+300
                                    M=M+3
                                Vi=Vi+5000
                                M=13
                        P1=0
                        P2=1
                        while Vm<=800:
                            t1=1400
                            while t1<=2600:
                                print('u_vus_foss_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                t1=t1+300
                            Vm=Vm+50
                    S2=0
            X4=1
            P1=1
            A1=1
            M=1
            Vi=10000
            Vm=400
            t1=1400
            S1=1
            S2=0
            while X4==1:
                X1=0
                X2=0
                X3=0
                while S1==1:
                    S2=0
                    while P1==1:
                        P2=0
                        while A1==1:
                            A2=0
                            while Vi<=60000:
                                while M<=12:
                                    t1=1400
                                    while t1<=2600:
                                        print('u_cam_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                        t1=t1+300
                                    M=M+3
                                Vi=Vi+5000
                                M=1
                            A1=0
                            A2=1
                            M=13
                            Vi=10000
                            while Vi<=60000:
                                while 13<=M<=120:
                                    t1=1400
                                    while t1<=2600:
                                        print('u_cam_foss_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                        t1=t1+300
                                    M=M+3
                                Vi=Vi+5000
                                M=13
                        P1=0
                        P2=1
                        while Vm<=800:
                            t1=1400
                            while t1<=2600:
                                print('u_cam_foss_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                t1=t1+300
                            Vm=Vm+50
                    S1=0
                    S2=1
                    P1=1
                    Vm=400
                    Vi=10000
                    A1=1
                    M=1
                    t1=1400
                    while S2==1:
                        while P1==1:
                            P2=0
                            while A1==1:
                                A2=0
                                while Vi<=60000:
                                    while M<=12:
                                        t1=1400
                                        while t1<=2600:
                                            print('u_cam_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                            t1=t1+300
                                        M=M+3
                                    Vi=Vi+5000
                                    M=1
                                A1=0
                                A2=1
                                M=13
                                Vi=10000
                                while Vi<=60000:
                                    while 13<=M<=120:
                                        t1=1400
                                        while t1<=2600:
                                            print('u_cam_foss_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                            t1=t1+300
                                        M=M+3
                                    Vi=Vi+5000
                                    M=13
                            P1=0
                            P2=1
                            while Vm<=800:
                                t1=1400
                                while t1<=2600:
                                    print('u_cam_foss_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                    t1=t1+300
                                Vm=Vm+50
                        S2=0
                X5=1
                P1=1
                A1=1
                M=1
                Vi=10000
                Vm=400
                t1=1400
                S1=1
                S2=0
                while X5==1:
                    X1=0
                    X2=0
                    X3=0
                    X4=0
                    while S1==1:
                        S2=0
                        while P1==1:
                            P2=0
                            while A1==1:
                                A2=0
                                while Vi<=60000:
                                    while M<=12:
                                        t1=1400
                                        while t1<=2600:
                                            print('u_b_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                            t1=t1+300
                                        M=M+3
                                    Vi=Vi+5000
                                    M=1
                                A1=0
                                A2=1
                                M=13
                                Vi=10000
                                while Vi<=60000:
                                    while 13<=M<=120:
                                        t1=1400
                                        while t1<=2600:
                                            print('u_b_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                            t1=t1+300
                                        M=M+3
                                    Vi=Vi+5000
                                    M=13
                            P1=0
                            P2=1
                            while Vm<=800:
                                t1=1400
                                while t1<=2600:
                                    print('u_b_hyb_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                    t1=t1+300
                                Vm=Vm+50
                        S1=0
                        S2=1
                        P1=1
                        Vm=400
                        Vi=10000
                        A1=1
                        M=1
                        t1=1400
                        while S2==1:
                            while P1==1:
                                P2=0
                                while A1==1:
                                    A2=0
                                    while Vi<=60000:
                                        while M<=12:
                                            t1=1400
                                            while t1<=2600:
                                                print('u_b_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                t1=t1+300
                                            M=M+3
                                        Vi=Vi+5000
                                        M=1
                                    A1=0
                                    A2=1
                                    M=13
                                    Vi=10000
                                    while Vi<=60000:
                                        while 13<=M<=120:
                                            t1=1400
                                            while t1<=2600:
                                                print('u_b_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                t1=t1+300
                                            M=M+3
                                        Vi=Vi+5000
                                        M=13
                                P1=0
                                P2=1
                                while Vm<=800:
                                    t1=1400
                                    while t1<=2600:
                                        print('u_b_hyb_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                        t1=t1+300
                                    Vm=Vm+50
                            S2=0
                    X6=1
                    P1=1
                    A1=1
                    M=1
                    Vi=10000
                    Vm=400
                    t1=1400
                    S1=1
                    S2=0
                    while X6==1:
                        X1=0
                        X2=0
                        X3=0
                        X4=0
                        X5=0
                        while S1==1:
                            S2=0
                            while P1==1:
                                P2=0
                                while A1==1:
                                    A2=0
                                    while Vi<=60000:
                                        while M<=12:
                                            t1=1400
                                            while t1<=2600:
                                                print('u_co_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                t1=t1+300
                                            M=M+3
                                        Vi=Vi+5000
                                        M=1
                                    A1=0
                                    A2=1
                                    M=13
                                    Vi=10000
                                    while Vi<=60000:
                                        while 13<=M<=120:
                                            t1=1400
                                            while t1<=2600:
                                                print('u_co_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                t1=t1+300
                                            M=M+3
                                        Vi=Vi+5000
                                        M=13
                                P1=0
                                P2=1
                                while Vm<=800:
                                    t1=1400
                                    while t1<=2600:
                                        print('u_co_hyb_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                        t1=t1+300
                                    Vm=Vm+50
                            S1=0
                            S2=1
                            P1=1
                            Vm=400
                            Vi=10000
                            A1=1
                            M=1
                            t1=1400
                            while S2==1:
                                while P1==1:
                                    P2=0
                                    while A1==1:
                                        A2=0
                                        while Vi<=60000:
                                            while M<=12:
                                                t1=1400
                                                while t1<=2600:
                                                    print('u_co_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                    t1=t1+300
                                                M=M+3
                                            Vi=Vi+5000
                                            M=1
                                        A1=0
                                        A2=1
                                        M=13
                                        Vi=10000
                                        while Vi<=60000:
                                            while 13<=M<=120:
                                                t1=1400
                                                while t1<=2600:
                                                    print('u_co_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                    t1=t1+300
                                                M=M+3
                                            Vi=Vi+5000
                                            M=13
                                    P1=0
                                    P2=1
                                    while Vm<=800:
                                        t1=1400
                                        while t1<=2600:
                                            print('u_co_hyb_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                            t1=t1+300
                                        Vm=Vm+50
                                S2=0
                        X7=1
                        P1=1
                        A1=1
                        M=1
                        Vi=10000
                        Vm=400
                        t1=1400
                        S1=1
                        S2=0
                        while X7==1:
                            X1=0
                            X2=0
                            X3=0
                            X4=0
                            X5=0
                            X6=0
                            while S1==1:
                                S2=0
                                while P1==1:
                                    P2=0
                                    while A1==1:
                                        A2=0
                                        while Vi<=60000:
                                            while M<=12:
                                                t1=1400
                                                while t1<=2600:
                                                    print('u_vus_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                    t1=t1+300
                                                M=M+3
                                            Vi=Vi+5000
                                            M=1
                                        A1=0
                                        A2=1
                                        M=13
                                        Vi=10000
                                        while Vi<=60000:
                                            while 13<=M<=120:
                                                t1=1400
                                                while t1<=2600:
                                                    print('u_vus_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                    t1=t1+300
                                                M=M+3
                                            Vi=Vi+5000
                                            M=13
                                    P1=0
                                    P2=1
                                    while Vm<=800:
                                        t1=1400
                                        while t1<=2600:
                                            print('u_vus_hyb_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                            t1=t1+300
                                        Vm=Vm+50
                                S1=0
                                S2=1
                                P1=1
                                Vm=400
                                Vi=10000
                                A1=1
                                M=1
                                t1=1400
                                while S2==1:
                                    while P1==1:
                                        P2=0
                                        while A1==1:
                                            A2=0
                                            while Vi<=60000:
                                                while M<=12:
                                                    t1=1400
                                                    while t1<=2600:
                                                        print('u_vus_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                        t1=t1+300
                                                    M=M+3
                                                Vi=Vi+5000
                                                M=1
                                            A1=0
                                            A2=1
                                            M=13
                                            Vi=10000
                                            while Vi<=60000:
                                                while 13<=M<=120:
                                                    t1=1400
                                                    while t1<=2600:
                                                        print('u_vus_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                        t1=t1+300
                                                    M=M+3
                                                Vi=Vi+5000
                                                M=13
                                        P1=0
                                        P2=1
                                        while Vm<=800:
                                            t1=1400
                                            while t1<=2600:
                                                print('u_vus_hyb_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                                t1=t1+300
                                            Vm=Vm+50
                                    S2=0
                            X8=1
                            P1=1
                            A1=1
                            M=1
                            Vi=10000
                            Vm=400
                            t1=1400
                            S1=1
                            S2=0
                            while X8==1:
                                X1=0
                                X2=0
                                X3=0
                                X4=0
                                X5=0
                                X6=0
                                X7=0
                                while S1==1:
                                    S2=0
                                    while P1==1:
                                        P2=0
                                        while A1==1:
                                            A2=0
                                            while Vi<=60000:
                                                while M<=12:
                                                    t1=1400
                                                    while t1<=2600:
                                                        print('u_cam_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                        t1=t1+300
                                                    M=M+3
                                                Vi=Vi+5000
                                                M=1
                                            A1=0
                                            A2=1
                                            M=13
                                            Vi=10000
                                            while Vi<=60000:
                                                while 13<=M<=120:
                                                    t1=1400
                                                    while t1<=2600:
                                                        print('u_cam_hyb_e_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                        t1=t1+300
                                                    M=M+3
                                                Vi=Vi+5000
                                                M=13
                                        P1=0
                                        P2=1
                                        while Vm<=800:
                                            t1=1400
                                            while t1<=2600:
                                                print('u_cam_hyb_e_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                                t1=t1+300
                                            Vm=Vm+50
                                    S1=0
                                    S2=1
                                    P1=1
                                    Vm=400
                                    Vi=10000
                                    A1=1
                                    M=1
                                    t1=1400
                                    while S2==1:
                                        while P1==1:
                                            P2=0
                                            while A1==1:
                                                A2=0
                                                while Vi<=60000:
                                                    while M<=12:
                                                        t1=1400
                                                        while t1<=2600:
                                                            print('u_cam_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                            t1=t1+300
                                                        M=M+3
                                                    Vi=Vi+5000
                                                    M=1
                                                A1=0
                                                A2=1
                                                M=13
                                                Vi=10000
                                                while Vi<=60000:
                                                    while 13<=M<=120:
                                                        t1=1400
                                                        while t1<=2600:
                                                            print('u_cam_hyb_d_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                            t1=t1+300
                                                        M=M+3
                                                    Vi=Vi+5000
                                                    M=13
                                            P1=0
                                            P2=1
                                            while Vm<=800:
                                                t1=1400
                                                while t1<=2600:
                                                    print('u_cam_hyb_d_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                                    t1=t1+300
                                                Vm=Vm+50
                                        S2=0
                                X9=1
                                P1=1
                                A1=1
                                M=1
                                Vi=10000
                                Vm=400
                                S1=0
                                S2=0
                                while X9==1:
                                    X1=0
                                    X2=0
                                    X3=0
                                    X4=0
                                    X5=0
                                    X6=0
                                    X7=0
                                    X8=0
                                    while P1==1:
                                        P2=0
                                        while A1==1:
                                            A2=0
                                            while Vi<=60000:
                                                while M<=12:
                                                    t1=1400
                                                    while t1<=2600:
                                                        print('u_b_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                        t1=t1+300
                                                    M=M+3
                                                Vi=Vi+5000
                                                M=1
                                            A1=0
                                            A2=1
                                            M=13
                                            Vi=10000
                                            while Vi<=60000:
                                                while 13<=M<=120:
                                                    t1=1400
                                                    while t1<=2600:
                                                        print('u_b_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                        t1=t1+300
                                                    M=M+3
                                                Vi=Vi+5000
                                                M=13
                                        P1=0
                                        P2=1
                                        while Vm<=800:
                                            t1=1400
                                            while t1<=2600:
                                                print('u_b_el_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                                t1=t1+300
                                            Vm=Vm+50
                                    X10=1
                                    P1=1
                                    A1=1
                                    M=1
                                    Vi=10000
                                    Vm=400
                                    while X10==1:
                                        X1=0
                                        X2=0
                                        X3=0
                                        X4=0
                                        X5=0
                                        X6=0
                                        X7=0
                                        X8=0
                                        X9=0
                                        while P1==1:
                                            P2=0
                                            while A1==1:
                                                A2=0
                                                while Vi<=60000:
                                                    while M<=12:
                                                        t1=1400
                                                        while t1<=2600:
                                                            print('u_co_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                            t1=t1+300
                                                        M=M+3
                                                    Vi=Vi+5000
                                                    M=1
                                                A1=0
                                                A2=1
                                                M=13
                                                Vi=10000
                                                while Vi<=60000:
                                                    while 13<=M<=120:
                                                        t1=1400
                                                        while t1<=2600:
                                                            print('u_co_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                            t1=t1+300
                                                        M=M+3
                                                    Vi=Vi+5000
                                                    M=13
                                            P1=0
                                            P2=1
                                            while Vm<=800:
                                                t1=1400
                                                while t1<=2600:
                                                    print('u_co_el_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                                    t1=t1+300
                                                Vm=Vm+50
                                        X11=1
                                        P1=1
                                        A1=1
                                        M=1
                                        Vi=10000
                                        Vm=400
                                        while X11==1:
                                            X1=0
                                            X2=0
                                            X3=0
                                            X4=0
                                            X5=0
                                            X6=0
                                            X7=0
                                            X8=0
                                            X9=0
                                            X10=0
                                            while P1==1:
                                                P2=0
                                                while A1==1:
                                                    A2=0
                                                    while Vi<=60000:
                                                        while M<=12:
                                                            t1=1400
                                                            while t1<=2600:
                                                                print('u_vus_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                                t1=t1+300
                                                            M=M+3
                                                        Vi=Vi+5000
                                                        M=1
                                                    A1=0
                                                    A2=1
                                                    M=13
                                                    Vi=10000
                                                    while Vi<=60000:
                                                        while 13<=M<=120:
                                                            t1=1400
                                                            while t1<=2600:
                                                                print('u_vus_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                                t1=t1+300
                                                            M=M+3
                                                        Vi=Vi+5000
                                                        M=13
                                                P1=0
                                                P2=1
                                                while Vm<=800:
                                                    t1=1400
                                                    while t1<=2600:
                                                        print('u_vus_el_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                                        t1=t1+300
                                                    Vm=Vm+50
                                            X12=1
                                            P1=1
                                            A1=1
                                            M=1
                                            Vi=10000
                                            Vm=400
                                            while X12==1:
                                                X1=0
                                                X2=0
                                                X3=0
                                                X4=0
                                                X5=0
                                                X6=0
                                                X7=0
                                                X8=0
                                                X9=0
                                                X10=0
                                                X11=0
                                                while P1==1:
                                                    P2=0
                                                    while A1==1:
                                                        A2=0
                                                        while Vi<=60000:
                                                            while M<=12:
                                                                t1=1400
                                                                while t1<=2600:
                                                                    print('u_cam_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                                    t1=t1+300
                                                                M=M+3
                                                            Vi=Vi+5000
                                                            M=1
                                                        A1=0
                                                        A2=1
                                                        M=13
                                                        Vi=10000
                                                        while Vi<=60000:
                                                            while 13<=M<=120:
                                                                t1=1400
                                                                while t1<=2600:
                                                                    print('u_cam_el_ach'+' '+str(t1)+' '+str(Vi)+' '+str(M)+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, a1:A1, a2:A2, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M})))
                                                                    t1=t1+300
                                                                M=M+3
                                                            Vi=Vi+5000
                                                            M=13
                                                    P1=0
                                                    P2=1
                                                    while Vm<=800:
                                                        t1=1400
                                                        while t1<=2600:
                                                            print('u_cam_el_lou'+' '+str(t1)+' '+str(Vm)+' '+'N/A'+' '+str(Ec2.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2}))+' '+str(Bc.subs({x1:X1, x2:X2, x3:X3, x4:X4, x5:X5, x6:X6, x7:X7, x8:X8, x9:X9, x10:X10, x11:X11, x12:X12, t:t1, s1:S1, s2:S2, p1:P1, p2:P2, vm:Vm, vi:Vi, m:M, a1:A1, a2:A2})))
                                                            t1=t1+300
                                                        Vm=Vm+50
                                                X12=0
# Out:
# u_b_foss_e_ach 1400 10000 1 275.310000000000 543.877001262483
# u_b_foss_e_ach 1700 10000 1 334.305000000000 581.300351262483
# u_b_foss_e_ach 2000 10000 1 393.300000000000 618.723701262483
# u_b_foss_e_ach 2300 10000 1 452.295000000000 656.147051262484
# u_b_foss_e_ach 2600 10000 1 511.290000000000 693.570401262483
# u_b_foss_e_ach 1400 10000 4 275.310000000000 533.880722806200
# u_b_foss_e_ach 1700 10000 4 334.305000000000 571.304072806200
# u_b_foss_e_ach 2000 10000 4 393.300000000000 608.727422806200
# u_b_foss_e_ach 2300 10000 4 452.295000000000 646.150772806200
# u_b_foss_e_ach 2600 10000 4 511.290000000000 683.574122806200
# u_b_foss_e_ach 1400 10000 7 275.310000000000 524.426826334911
# u_b_foss_e_ach 1700 10000 7 334.305000000000 561.850176334911
# u_b_foss_e_ach 2000 10000 7 393.300000000000 599.273526334911
# u_b_foss_e_ach 2300 10000 7 452.295000000000 636.696876334911
# u_b_foss_e_ach 2600 10000 7 511.290000000000 674.120226334911
# ...

# %%
from IPython.core.display import display, HTML
display(HTML('<style>.container {width: 100% !important}</style>'))
# Out:
# <style>.container {width: 100% !important}</style>

# %%
jupyter nbconvert --to webpdf --allow-chromium-download your-notebook-file.ipynb
# Out:
#   File "C:\Users\cedri\AppData\Local\Temp\ipykernel_17468\514470026.py", line 1
#     jupyter nbconvert --to webpdf --allow-chromium-download your-notebook-file.ipynb
#             ^
# SyntaxError: invalid syntax
